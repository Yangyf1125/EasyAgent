# %%
from langgraph.prebuilt import create_react_agent
import os
os.environ["TAVILY_API_KEY"] = "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"
os.environ["DEEPSEEK_API_KEY"] = "sk-2574248e129a44cbbb543c8ffcceeec8"
from langchain_deepseek import ChatDeepSeek

llm = ChatDeepSeek(
    model="deepseek-chat", 
    base_url="https://api.deepseek.com",
    api_key="sk-2574248e129a44cbbb543c8ffcceeec8",
    temperature=0
)

from langchain_community.tools.tavily_search import TavilySearchResults

tools = [TavilySearchResults(max_results=3)]
agent = create_react_agent("deepseek:deepseek-chat", tools)

# %%
agent_response = agent.invoke(
    {"messages": [("user", "收集新能源股票的相关数据，包括但不限于股价走势、成交量、市盈率等。时间范围为2025-03-01至2025-05-28")]}
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(agent.invoke(
#       2     {"messages": [("user", "收集新能源股票的相关数据，包括但不限于股价走势、成交量、市盈率等。时间范围为2025-03-01至2025-05-28。")]}
#       3 ))
#
# File c:\anaconda\envs\open_manus\Lib\site-packages\langgraph\pregel\__init__.py:2894, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, **kwargs)
#    2891 chunks: list[Union[dict[str, Any], Any]] = []
#    2892 interrupts: list[Interrupt] = []
# -> 2894 for chunk in self.stream(
#    2895     input,
#    2896     config,
#    2897     stream_mode=stream_mode,
#    2898     output_keys=output_keys,
#    2899     interrupt_before=interrupt_before,
#    2900     interrupt_after=interrupt_after,
#    2901     checkpoint_during=checkpoint_during,
#    2902     debug=debug,
# ...

# %%
agent_response["messages"][-1].content
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 agent_response["messages"][-1].content
#
# TypeError: 'coroutine' object is not subscriptable
